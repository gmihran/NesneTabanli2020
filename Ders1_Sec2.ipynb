# %%
print("Merhaba")
# Out:
# Merhaba

# %% [markdown]
# Burada ekrana Merhaba çıktısı veririz

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
a=20

# %%
print(a)
# Out:
# 20

# %%
a=10
print(a)
# Out:
# 10
